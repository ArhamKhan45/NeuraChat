# %% [markdown]
# Frontend
#      │
#      ▼
# FastAPI
#      │
#      ▼
# LangGraph
#      │
#  ┌───┴──────────┐
#  │              │
#  ▼              ▼
# Router      Supervisor
#  │              │
#  ├─────┬────────┤
#  ▼     ▼        ▼
# Code  RAG   Planning
# Agent Agent   Agent
#  │
#  ▼
# Vector DB
#  │
#  ▼
# Embeddings
#  │
#  ▼
# vLLM
#  │
#  ▼
# Local Llama/Qwen

# %% [markdown]
# put it in md file Multi-Agent RAG Orchestration Framework  Engineered an autonomous AI agent platform using LangGraph and LangChain for complex task planning and contextual routing.  Implemented a Retrieval-Augmented Generation (RAG) pipeline using high-dimensional Embeddings and Vector DBs, deploying local LLMs via vLLM and FastAPI for low-latency inference.

# %% [markdown]
# Router Agent – Determines the optimal execution path for every user request.
# Planner Agent – Breaks complex tasks into logical execution steps.
# Research Agent – Retrieves relevant knowledge from external and internal sources.
# RAG Agent – Performs semantic retrieval from the vector database.
# Response Agent – Generates accurate, context-aware responses.
# Memory Agent – Maintains conversation history and contextual memory.
# Tool Agent – Executes APIs, functions, and external tools.
# Supervisor Agent – Coordinates collaboration between all AI agents.
