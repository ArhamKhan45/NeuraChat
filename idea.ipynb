# %% [markdown]
# Projects
# Multi-Agent RAG Orchestration Framework
#  Engineered an autonomous AI agent platform using LangGraph and LangChain for complex task
# planning and contextual routing.
#  Implemented a Retrieval-Augmented Generation (RAG) pipeline using high-dimensional Embeddings
# and Vector DBs, deploying local LLMs via vLLM and FastAPI for low-latency inference.
#
#
#
#
# Predictive Analytics & Risk Assessment Engine
#  Built an end-to-end machine learning system using Scikit-learn and CatBoost to classify and predict
# high-risk transactional patterns.
#  Streamlined large-scale feature engineering pipelines using Pandas and NumPy, querying optimized
# PostgreSQL datasets to serve real-time model predictions.
